# %%
import numpy as np

# %%
# !pip3 install numpy
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip

# %%
arr1d=np.arange(1,11)
arr2d=np.random.randint(1,1000 , size=(3,3))

sum1=arr1d.sum()
sum2=arr2d.sum()
mean1=arr1d.mean()
mean2=arr2d.mean()
maximum1=arr1d.max()
maximum2=arr2d.max()

arr1d_mult=arr1d * 2
arr2d_mult=arr2d * 2

arrd1_chg=arr1d.copy()
arrd2_chg=arr2d.copy()

arr1d_chg[arr1d_chg > 5] = 0
arr2d_chg[arr2d_chg > 5] = 0

print(f"array 1D sum={sum1}, mean={mean1}, max={max1}, 2 multiplication:{arr1d_mult}, change the 5 to 0:{arr1d_chg} ")
print(f"array 2D sum={sum2}, mean={mean2}, max={max2}, 2 multiplication:{arr2d_mult}, change the 5 to 0:{arr2d_chg} ")
